# %% [markdown]
# # AI & ML Internship
#
# **Name:** Manish Saini
# **Organization:** Codomax Digital Solutions

# %% [markdown]
# # Day 1 - Environment Setup & First Python Program
#
# ## Objective
# - Set up the Python development environment.
# - Write and execute the first Python program.
# - Verify that the development environment is working correctly.

# %%
# Print a welcome message
print("Hello, Codomax!")

# Display internship information
print("My name is Manish Saini")
print("This is my first AI & ML Internship task.")
# Out:
# Hello, Codomax!
# My name is Manish Saini
# This is my first AI & ML Internship task.

# %% [markdown]
# ## Output
#
# The program successfully prints the welcome message and internship details.
