# %% [markdown]
# # Day 2 - Python Basics
#
# **Name:** Manish Saini
#
# **Internship:** AI & ML Internship
#
# **Organization:** Codomax Digital Solutions

# %%
name = "Manish"
age = 21
cgpa = 8.5
is_intern = True

print(f"Name: {name} (Type: {type(name)})")
print(f"Age: {age} (Type: {type(age)})")
print(f"CGPA: {cgpa} (Type: {type(cgpa)})")
print(f"Is Intern: {is_intern} (Type: {type(is_intern)})")
# Out:
# Name: Manish (Type: <class 'str'>)
# Age: 21 (Type: <class 'int'>)
# CGPA: 8.5 (Type: <class 'float'>)
# Is Intern: True (Type: <class 'bool'>)

# %%
print(type(name))
print(type(age))
print(type(cgpa))
print(type(is_intern))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
a = 15
b = 4

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Modulus:", a % b)
print("Power:", a ** b)
# Out:
# Addition: 19
# Subtraction: 11
# Multiplication: 60
# Division: 3.75
# Modulus: 3
# Power: 50625

# %%
marks = 85

if marks >= 40:
    print("Pass")
else:
    print("Fail")
# Out:
# Pass

# %%
for i in range(1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
count = 1

while count <= 5:
    print(count)
    count += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
def greet(name):
    return f"Welcome {name}!"

print(greet("Manish"))
def square(number):
    return number ** 2

num = 7
print("Square =", square(num))
# Out:
# Welcome Manish!
# Square = 49

# %% [markdown]
# # Conclusion
#
# Successfully learned Python variables, data types, operators, loops, conditional statements, and functions by implementing simple Python programs.
